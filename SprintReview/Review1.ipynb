# %%
using System;
using System.Collections.Generic;

public class Product
{
    private string name;
    private decimal price;
    private int quantity;

    protected string category;
    internal string description;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public decimal Price
    {
        get { return price; }
        set
        {
            if (value >= 0)
                price = value;
        }
    }

    public int Quantity
    {
        get { return quantity; }
        set
        {
            if (value >= 0)
                quantity = value;
        }
    }

    public string Category
    {
        get { return category; }
        set { category = value; }
    }

    public string Description
    {
        get { return description; }
        set { description = value; }
    }

    public Product(
        string name,
        decimal price,
        int quantity,
        string category,
        string description)
    {
        Name = name;
        Price = price;
        Quantity = quantity;
        Category = category;
        Description = description;
    }

    public decimal GetTotalPrice()
    {
        return Price * Quantity;
    }

    public void UpdateQuantity(int amount)
    {
        Quantity += amount;
    }

    public string GetProductInfo()
    {
        return $"Товар: {Name}, цена: {Price}, количество: {Quantity}, категория: {Category}, описание: {Description}";
    }
}

public class Seller
{
    private string name;
    private string employeeId;
    private List<Product> products = new List<Product>();

    protected decimal salary;
    internal string contactInfo;

    public string Name
    {
        get { return name; }
        set { name = value; }
    }

    public string EmployeeId
    {
        get { return employeeId; }
        set { employeeId = value; }
    }

    public decimal Salary
    {
        get { return salary; }
        set { salary = value; }
    }

    public string ContactInfo
    {
        get { return contactInfo; }
        set { contactInfo = value; }
    }

    public Seller(
        string name,
        string employeeId,
        decimal salary,
        string contactInfo)
    {
        Name = name;
        EmployeeId = employeeId;
        Salary = salary;
        ContactInfo = contactInfo;
    }

    public void AddProduct(Product product)
    {
        products.Add(product);
        Console.WriteLine($"Товар {product.Name} добавлен продавцу {Name}.");
    }

    public void SellProduct(Product product, int quantity)
    {
        if (product.Quantity >= quantity)
        {
            product.UpdateQuantity(-quantity);
            Console.WriteLine($"{Name} продал товар {product.Name}: {quantity} шт.");
        }
        else
        {
            Console.WriteLine("Недостаточно товара.");
        }
    }

    public string GetSellerInfo()
    {
        return $"Продавец: {Name}, ID: {EmployeeId}, контакт: {ContactInfo}";
    }

    public List<Product> GetProducts()
    {
        return products;
    }
}

public class Store
{
    private string storeName;
    private string location;
    private List<Seller> sellers = new List<Seller>();

    public string storeHours;

    public string StoreName
    {
        get { return storeName; }
        set { storeName = value; }
    }

    public string Location
    {
        get { return location; }
        set { location = value; }
    }

    public Store(string storeName, string location, string hours)
    {
        StoreName = storeName;
        Location = location;
        storeHours = hours;
    }

    public void AddSeller(Seller seller)
    {
        sellers.Add(seller);
        Console.WriteLine($"Продавец {seller.Name} добавлен в магазин.");
    }

    public void ListProducts()
    {
        Console.WriteLine("Товары в магазине:");

        foreach (Seller seller in sellers)
        {
            foreach (Product product in seller.GetProducts())
            {
                Console.WriteLine(product.GetProductInfo());
            }
        }
    }

    public string GetStoreInfo()
    {
        return $"Магазин: {StoreName}, адрес: {Location}, часы работы: {storeHours}";
    }
}

Product product = new Product(
    "Ноутбук",
    50000m,
    10,
    "Электроника",
    "Ноутбук для работы"
);

Seller seller = new Seller(
    "Анна",
    "S001",
    50000m,
    "anna@mail.ru"
);

Store store = new Store(
    "Tech Store",
    "Москва",
    "10:00 - 20:00"
);

seller.AddProduct(product);
store.AddSeller(seller);

Console.WriteLine();
Console.WriteLine(product.GetProductInfo());
Console.WriteLine($"Общая стоимость: {product.GetTotalPrice()}");

Console.WriteLine();
Console.WriteLine(seller.GetSellerInfo());

seller.SellProduct(product, 2);

Console.WriteLine();
store.ListProducts();

Console.WriteLine();
Console.WriteLine(store.GetStoreInfo());
# Out:
# Товар Ноутбук добавлен продавцу Анна.
# Продавец Анна добавлен в магазин.
#
# Товар: Ноутбук, цена: 50000, количество: 10, категория: Электроника, описание: Ноутбук для работы
# Общая стоимость: 500000
#
# Продавец: Анна, ID: S001, контакт: anna@mail.ru
# Анна продал товар Ноутбук: 2 шт.
#
# Товары в магазине:
# Товар: Ноутбук, цена: 50000, количество: 8, категория: Электроника, описание: Ноутбук для работы
#
# Магазин: Tech Store, адрес: Москва, часы работы: 10:00 - 20:00
